# %%
import pandas as pd
import numpy as np
import os, sys

os.getcwd()
rpath = os.path.abspath('../')
if rpath not in sys.path:
    sys.path.insert(0,rpath)

# %%
train_path = os.path.join(rpath, 'telegram_data.csv')
df = pd.read_csv(train_path)  # Tab-delimited

df
# Out:
#           Channel Title Channel Username     ID  \
# 0     SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14841
# 1     SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14840
# 2     SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14839
# 3     SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14838
# 4     SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14837
# ...                 ...              ...    ...
# 4618  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    599
# 4619  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    598
# 4620  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    197
# 4621  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    182
# 4622  SINA KIDS/ሲና ኪድስⓇ        @sinayelj      1
#
#                                                 Message  \
# 0                                                   NaN
# 1                                                   NaN
# 2     ለኮንዶሚኒየም ለጠባብ ቤቶች ገላግሌ የሆነ ከንፁህ የሲልከን ጥሬ እቃ የተ...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4618                                                NaN
# 4619                 Baby potty\n0905707448\n0945097042
# 4620                                                NaN
# 4621  ውድ የሲና ኪድስ ደምበኞች በድጋሚ ገብቷል \nየመዋኛ ገንዳ ትልቅ ሳይዝ ...
# 4622                                                NaN
#
#                            Date                  Media Path
# 0     2024-09-26 12:24:51+00:00  photos\@sinayelj_14841.jpg
# 1     2024-09-26 12:24:51+00:00  photos\@sinayelj_14840.jpg
# 2     2024-09-26 12:24:51+00:00  photos\@sinayelj_14839.jpg
# 3     2024-09-26 12:24:12+00:00  photos\@sinayelj_14838.jpg
# 4     2024-09-26 12:24:12+00:00  photos\@sinayelj_14837.jpg
# ...                         ...                         ...
# 4618  2021-04-16 18:12:10+00:00    photos\@sinayelj_599.jpg
# 4619  2021-04-16 18:12:10+00:00    photos\@sinayelj_598.jpg
# 4620  2020-11-26 18:30:52+00:00                         NaN
# 4621  2020-11-10 06:59:31+00:00    photos\@sinayelj_182.jpg
# 4622  2020-07-24 10:50:43+00:00                         NaN
#
# [4623 rows x 6 columns]

# %%
df.dropna()
# Out:
#           Channel Title Channel Username     ID  \
# 2     SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14839
# 6     SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14835
# 9     SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14832
# 16    SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14825
# 26    SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14815
# ...                 ...              ...    ...
# 4611  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    674
# 4613  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    640
# 4615  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    605
# 4619  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    598
# 4621  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    182
#
#                                                 Message  \
# 2     ለኮንዶሚኒየም ለጠባብ ቤቶች ገላግሌ የሆነ ከንፁህ የሲልከን ጥሬ እቃ የተ...
# 6     Baby romper   ከላዩ ፈር ውስጡ ኮተን የሆነ\n\n2000 birr\...
# 9     Chicco 5 in 1 mama bag\nኦሪጅናል ማቴሪያል\nበሳይዙ ትልቅ\...
# 16    aiebao HIP SEAT CARRIER\nምቹ ጠንካራ የልጆች ማዘያ\nበተለ...
# 26    Kids mat  \n\n💥4100 ብር\n\nSize 1.80*2m\n\nfree...
# ...                                                 ...
# 4611  ምቹ የልጆች ፖፖ የሶፍት ማስቀመጫ ያለው 1000ብር\nFree deliver...
# 4613  ለልጆች ምቹ እና ኮንፈርተብል ማት \nከላይ ማጫወቻ ያለዉ ከተፈለገ ማጫወ...
# 4615  Baby potty \nበባትሪ የሚሰራ ድምፅ ያለው\nየልጆች ፖፖ 899 ብር...
# 4619                 Baby potty\n0905707448\n0945097042
# 4621  ውድ የሲና ኪድስ ደምበኞች በድጋሚ ገብቷል \nየመዋኛ ገንዳ ትልቅ ሳይዝ ...
#
#                            Date                  Media Path
# 2     2024-09-26 12:24:51+00:00  photos\@sinayelj_14839.jpg
# 6     2024-09-26 12:24:11+00:00  photos\@sinayelj_14835.jpg
# 9     2024-09-26 12:20:22+00:00  photos\@sinayelj_14832.jpg
# 16    2024-09-26 12:19:20+00:00  photos\@sinayelj_14825.jpg
# 26    2024-09-25 06:15:53+00:00  photos\@sinayelj_14815.jpg
# ...                         ...                         ...
# 4611  2021-04-28 19:12:19+00:00    photos\@sinayelj_674.jpg
# 4613  2021-04-20 11:16:59+00:00    photos\@sinayelj_640.jpg
# 4615  2021-04-16 18:27:22+00:00    photos\@sinayelj_605.jpg
# 4619  2021-04-16 18:12:10+00:00    photos\@sinayelj_598.jpg
# 4621  2020-11-10 06:59:31+00:00    photos\@sinayelj_182.jpg
#
# [1283 rows x 6 columns]

# %%
print("Checking for NaN values in the 'Message' column:")
nan_count = df['Message'].isnull().sum()
print(f"Number of NaN values in 'Message' column: {nan_count}")
# Out:
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 3268

# %%
df = df.dropna(subset=['Message'])

# Print the shape of the dataset after dropping NaN values in the "Message" column
print(f"Dataset shape after dropping NaN values in 'Message' column: {df.shape}")
# Out:
# Dataset shape after dropping NaN values in 'Message' column: (1355, 6)

# %%
df.head()
# Out:
#         Channel Title Channel Username     ID  \
# 2   SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14839
# 6   SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14835
# 9   SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14832
# 16  SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14825
# 26  SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14815
#
#                                               Message  \
# 2   ለኮንዶሚኒየም ለጠባብ ቤቶች ገላግሌ የሆነ ከንፁህ የሲልከን ጥሬ እቃ የተ...
# 6   Baby romper   ከላዩ ፈር ውስጡ ኮተን የሆነ\n\n2000 birr\...
# 9   Chicco 5 in 1 mama bag\nኦሪጅናል ማቴሪያል\nበሳይዙ ትልቅ\...
# 16  aiebao HIP SEAT CARRIER\nምቹ ጠንካራ የልጆች ማዘያ\nበተለ...
# 26  Kids mat  \n\n💥4100 ብር\n\nSize 1.80*2m\n\nfree...
#
#                          Date                  Media Path
# 2   2024-09-26 12:24:51+00:00  photos\@sinayelj_14839.jpg
# 6   2024-09-26 12:24:11+00:00  photos\@sinayelj_14835.jpg
# 9   2024-09-26 12:20:22+00:00  photos\@sinayelj_14832.jpg
# 16  2024-09-26 12:19:20+00:00  photos\@sinayelj_14825.jpg
# 26  2024-09-25 06:15:53+00:00  photos\@sinayelj_14815.jpg

# %%
message_df=df['Message']
message_df
# Out:
# 2       ለኮንዶሚኒየም ለጠባብ ቤቶች ገላግሌ የሆነ ከንፁህ የሲልከን ጥሬ እቃ የተ...
# 6       Baby romper   ከላዩ ፈር ውስጡ ኮተን የሆነ\n\n2000 birr\...
# 9       Chicco 5 in 1 mama bag\nኦሪጅናል ማቴሪያል\nበሳይዙ ትልቅ\...
# 16      aiebao HIP SEAT CARRIER\nምቹ ጠንካራ የልጆች ማዘያ\nበተለ...
# 26      Kids mat  \n\n💥4100 ብር\n\nSize 1.80*2m\n\nfree...
#                               ...
# 4611    ምቹ የልጆች ፖፖ የሶፍት ማስቀመጫ ያለው 1000ብር\nFree deliver...
# 4613    ለልጆች ምቹ እና ኮንፈርተብል ማት \nከላይ ማጫወቻ ያለዉ ከተፈለገ ማጫወ...
# 4615    Baby potty \nበባትሪ የሚሰራ ድምፅ ያለው\nየልጆች ፖፖ 899 ብር...
# 4619                   Baby potty\n0905707448\n0945097042
# 4621    ውድ የሲና ኪድስ ደምበኞች በድጋሚ ገብቷል \nየመዋኛ ገንዳ ትልቅ ሳይዝ ...
# Name: Message, Length: 1355, dtype: object

# %%
# Example of your DataFrame
# df = pd.DataFrame({'Message': ['💥3pcs silicon brush spatulas...', '💥Mandoline Slicer...', ...]})

# Define a function to remove emojis
def remove_emojis(text):
    emoji_pattern = re.compile(
        "[" 
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F700-\U0001F77F"  # alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251" 
        "]+", 
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

# Apply the function to the 'Message' column
df['Message'] = df['Message'].apply(remove_emojis)

# Display the updated DataFrame
df.head()
# Out:
# C:\Users\AII\AppData\Local\Temp\ipykernel_2612\1567010175.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Message'] = df['Message'].apply(remove_emojis)
#         Channel Title Channel Username     ID  \
# 2   SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14839
# 6   SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14835
# 9   SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14832
# 16  SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14825
# 26  SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14815
#
#                                               Message  \
# 2   ለኮንዶሚኒየም ለጠባብ ቤቶች ገላግሌ የሆነ ከንፁህ የሲልከን ጥሬ እቃ የተ...
# 6   Baby romper   ከላዩ ፈር ውስጡ ኮተን የሆነ\n\n2000 birr\...
# 9   Chicco 5 in 1 mama bag\nኦሪጅናል ማቴሪያል\nበሳይዙ ትልቅ\...
# 16  aiebao HIP SEAT CARRIER\nምቹ ጠንካራ የልጆች ማዘያ\nበተለ...
# 26  Kids mat  \n\n4100 ብር\n\nSize 1.80*2m\n\nfree ...
#
#                          Date                  Media Path
# 2   2024-09-26 12:24:51+00:00  photos\@sinayelj_14839.jpg
# 6   2024-09-26 12:24:11+00:00  photos\@sinayelj_14835.jpg
# 9   2024-09-26 12:20:22+00:00  photos\@sinayelj_14832.jpg
# 16  2024-09-26 12:19:20+00:00  photos\@sinayelj_14825.jpg
# 26  2024-09-25 06:15:53+00:00  photos\@sinayelj_14815.jpg

# %%
path = os.path.join(rpath, 'data', 'clean_data.csv')
df.to_csv(path, index=False)

# %%
import torch
print(torch.__version__)
# Out:
# 2.4.1+cpu

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
from tenacity import retry, stop_after_attempt, wait_exponential

# Retry decorator
@retry(stop=stop_after_attempt(5), wait=wait_exponential(multiplier=1, min=2, max=10))
def load_model():
    tokenizer = AutoTokenizer.from_pretrained("masakhane/afroxlmr-large-ner-masakhaner-1.0_2.0")
    model = AutoModelForTokenClassification.from_pretrained("masakhane/afroxlmr-large-ner-masakhaner-1.0_2.0")
    return tokenizer, model

tokenizer, model = load_model()
nlp = pipeline("ner", model=model, tokenizer=tokenizer)

# Example usage
example = df['Message'][10]
ner_results = nlp(example)
print(ner_results)
# Out:
# Error while downloading from https://cdn-lfs.hf.co/repos/fa/39/fa39c3e7e2b904627c4b398a1d015cbbe87073c00877f07ebfe52832984dd391/e4cedefc3e3a767442d6dbbeb30973ea0628b79cafe3f637f62607d02ebcc652?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27model.safetensors%3B+filename%3D%22model.safetensors%22%3B&Expires=1727670552&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=CcA0QYo90SJa9QDUL%7Eb%7EXfEXS5yFmyuE1UQabJLej8QGIxzHo6LTS4UtB-%7EDm%7E3UsJ9MdZE-LDxZLHSG3luahgfi3IYT83rt5vu4O0zBbM2W5-Hs1Sw7dHx%7Ev9YhiZE4n%7EZr5BMhVsFOymcEPUC2E%7EKRzcLnadFuEBf331CFoAeRra3VmnvfvoPoHGyYRsDSaYOsDurB6uL98ED5ouz7LI9dnvkzLEF94GeRvNLpCloppKPUj9bICIxGSz3AHXJ6orHCKikdawLViEk8Z0jBmQGUDksPbuMxMAtBfm1Az4xBCMfTnLMBqo30cRqvDj0kWmbbvE-x8OJvrJhnwDi3Uw__&Key-Pair-Id=K3RPWS32NSSJCE: HTTPSConnectionPool(host='cdn-lfs.hf.co', port=443): Read timed out.
# Trying to resume download...
# [{'entity': 'B-LOC', 'score': 0.99454147, 'index': 250, 'word': '▁', 'start': 567, 'end': 568}, {'entity': 'B-LOC', 'score': 0.94575375, 'index': 251, 'word': 'ገር', 'start': 567, 'end': 569}, {'entity': 'I-LOC', 'score': 0.99348336, 'index': 252, 'word': 'ጂ', 'start': 569, 'end': 570}, {'entity': 'I-LOC', 'score': 0.9934176, 'index': 253, 'word': '▁ኢ', 'start': 571, 'end': 572}, {'entity': 'I-LOC', 'score': 0.8891281, 'index': 254, 'word': 'ም', 'start': 572, 'end': 573}, {'entity': 'I-LOC', 'score': 0.97555643, 'index': 255, 'word': 'ፔ', 'start': 573, 'end': 574}, {'entity': 'I-LOC', 'score': 0.98868996, 'index': 256, 'word': 'ሪያ', 'start': 574, 'end': 576}, {'entity': 'I-LOC', 'score': 0.9036381, 'index': 257, 'word': 'ል', 'start': 576, 'end': 577}, {'entity': 'I-LOC', 'score': 0.87048745, 'index': 258, 'word': '▁ከ', 'start': 578, 'end': 579}, {'entity': 'I-LOC', 'score': 0.5726581, 'index': 259, 'word': 'ሳ', 'start': 579, 'end': 580}, {'entity': 'I-LOC', 'score': 0.96504873, 'index': 260, 'word': 'ሚ', 'start': 580, 'end': 581}, {'entity': 'I-LOC', 'score': 0.9729134, 'index': 261, 'word': '▁', 'start': 582, 'end': 583}, {'entity': 'I-LOC', 'score': 0.9190842, 'index': 262, 'word': 'ህን', 'start': 582, 'end': 584}, {'entity': 'I-LOC', 'score': 0.9518734, 'index': 263, 'word': 'ፃ', 'start': 584, 'end': 585}, {'entity': 'B-LOC', 'score': 0.89005923, 'index': 266, 'word': '▁አልፎ', 'start': 589, 'end': 592}, {'entity': 'I-LOC', 'score': 0.98671013, 'index': 267, 'word': 'ዝ', 'start': 592, 'end': 593}, {'entity': 'I-LOC', 'score': 0.9975956, 'index': 268, 'word': '▁', 'start': 594, 'end': 595}, {'entity': 'I-LOC', 'score': 0.99536186, 'index': 269, 'word': 'ፕ', 'start': 594, 'end': 595}, {'entity': 'I-LOC', 'score': 0.9960671, 'index': 270, 'word': 'ላ', 'start': 595, 'end': 596}, {'entity': 'I-LOC', 'score': 0.9958391, 'index': 271, 'word': 'ዛ', 'start': 596, 'end': 597}, {'entity': 'I-LOC', 'score': 0.94472647, 'index': 272, 'word': '▁', 'start': 598, 'end': 599}, {'entity': 'I-LOC', 'score': 0.5568019, 'index': 273, 'word': 'ግራ', 'start': 598, 'end': 600}, {'entity': 'I-LOC', 'score': 0.7648871, 'index': 274, 'word': 'ውን', 'start': 600, 'end': 602}, {'entity': 'B-ORG', 'score': 0.5604393, 'index': 290, 'word': '▁', 'start': 631, 'end': 632}, {'entity': 'I-ORG', 'score': 0.9142032, 'index': 291, 'word': 'ቅድስት', 'start': 631, 'end': 635}, {'entity': 'I-ORG', 'score': 0.9899657, 'index': 292, 'word': '▁', 'start': 636, 'end': 637}, {'entity': 'I-ORG', 'score': 0.96469235, 'index': 293, 'word': 'ስላሴ', 'start': 636, 'end': 639}, {'entity': 'I-LOC', 'score': 0.5512547, 'index': 294, 'word': '▁', 'start': 640, 'end': 641}, {'entity': 'I-LOC', 'score': 0.56163913, 'index': 295, 'word': 'ህን', 'start': 640, 'end': 642}, {'entity': 'I-LOC', 'score': 0.8959731, 'index': 296, 'word': 'ፃ', 'start': 642, 'end': 643}, {'entity': 'B-ORG', 'score': 0.969523, 'index': 299, 'word': '▁ከ', 'start': 649, 'end': 650}, {'entity': 'I-ORG', 'score': 0.85716313, 'index': 300, 'word': 'ብል', 'start': 650, 'end': 652}, {'entity': 'I-ORG', 'score': 0.98222697, 'index': 301, 'word': 'ፅ', 'start': 652, 'end': 653}, {'entity': 'I-ORG', 'score': 0.98948574, 'index': 302, 'word': 'ግ', 'start': 653, 'end': 654}, {'entity': 'I-ORG', 'score': 0.97898567, 'index': 303, 'word': 'ና', 'start': 654, 'end': 655}, {'entity': 'I-ORG', 'score': 0.9148753, 'index': 304, 'word': '▁ዋና', 'start': 656, 'end': 658}, {'entity': 'I-ORG', 'score': 0.92563194, 'index': 305, 'word': 'ፅ', 'start': 658, 'end': 659}, {'entity': 'I-ORG', 'score': 0.94848007, 'index': 306, 'word': 'ፈት', 'start': 659, 'end': 661}, {'entity': 'I-ORG', 'score': 0.9619417, 'index': 307, 'word': '▁ቤት', 'start': 662, 'end': 664}, {'entity': 'B-LOC', 'score': 0.99629956, 'index': 333, 'word': '▁', 'start': 714, 'end': 715}, {'entity': 'I-LOC', 'score': 0.772787, 'index': 334, 'word': 'ቀይ', 'start': 714, 'end': 716}, {'entity': 'I-LOC', 'score': 0.9995183, 'index': 335, 'word': '▁ሸ', 'start': 717, 'end': 718}, {'entity ...

# %%
ner_results.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 ner_results.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
df
# Out:
#       Unnamed: 0      Channel Title Channel Username     ID  \
# 0              2  SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14839
# 1              6  SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14835
# 2              9  SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14832
# 3             16  SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14825
# 4             26  SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14815
# ...          ...                ...              ...    ...
# 1350        4611  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    674
# 1351        4613  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    640
# 1352        4615  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    605
# 1353        4619  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    598
# 1354        4621  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    182
#
#                                                 Message  \
# 0     ለኮንዶሚኒየም ለጠባብ ቤቶች ገላግሌ የሆነ ከንፁህ የሲልከን ጥሬ እቃ የተ...
# 1     Baby romper   ከላዩ ፈር ውስጡ ኮተን የሆነ\n\n2000 birr\...
# 2     Chicco 5 in 1 mama bag\nኦሪጅናል ማቴሪያል\nበሳይዙ ትልቅ\...
# 3     aiebao HIP SEAT CARRIER\nምቹ ጠንካራ የልጆች ማዘያ\nበተለ...
# 4     Kids mat  \n\n4100 ብር\n\nSize 1.80*2m\n\nfree ...
# ...                                                 ...
# 1350  ምቹ የልጆች ፖፖ የሶፍት ማስቀመጫ ያለው 1000ብር\nFree deliver...
# 1351  ለልጆች ምቹ እና ኮንፈርተብል ማት \nከላይ ማጫወቻ ያለዉ ከተፈለገ ማጫወ...
# 1352  Baby potty \nበባትሪ የሚሰራ ድምፅ ያለው\nየልጆች ፖፖ 899 ብር...
# 1353                 Baby potty\n0905707448\n0945097042
# 1354  ውድ የሲና ኪድስ ደምበኞች በድጋሚ ገብቷል \nየመዋኛ ገንዳ ትልቅ ሳይዝ ...
#
#                            Date                  Media Path  \
# 0     2024-09-26 12:24:51+00:00  photos\@sinayelj_14839.jpg
# 1     2024-09-26 12:24:11+00:00  photos\@sinayelj_14835.jpg
# 2     2024-09-26 12:20:22+00:00  photos\@sinayelj_14832.jpg
# 3     2024-09-26 12:19:20+00:00  photos\@sinayelj_14825.jpg
# 4     2024-09-25 06:15:53+00:00  photos\@sinayelj_14815.jpg
# ...                         ...                         ...
# 1350  2021-04-28 19:12:19+00:00    photos\@sinayelj_674.jpg
# 1351  2021-04-20 11:16:59+00:00    photos\@sinayelj_640.jpg
# 1352  2021-04-16 18:27:22+00:00    photos\@sinayelj_605.jpg
# 1353  2021-04-16 18:12:10+00:00    photos\@sinayelj_598.jpg
# 1354  2020-11-10 06:59:31+00:00    photos\@sinayelj_182.jpg
#
#                                         Labeled_Message
# 0     ለኮንዶሚኒየም B-PRODUCT\nለጠባብ I-PRODUCT\nቤቶች I-PROD...
# 1     Baby B-PRODUCT\nromper I-PRODUCT\nከላዩ I-PRODUC...
# 2     Chicco B-PRODUCT\n5 I-PRODUCT\nin I-PRODUCT\n1...
# 3     aiebao B-PRODUCT\nHIP I-PRODUCT\nSEAT I-PRODUC...
# 4     Kids B-PRODUCT\nmat I-PRODUCT\n4100 I-PRICE\nብ...
# ...                                                 ...
# 1350  ምቹ B-PRODUCT\nየልጆች I-PRODUCT\nፖፖ I-PRODUCT\nየሶ...
# 1351  ለልጆች B-PRODUCT\nምቹ I-PRODUCT\nእና I-PRODUCT\nኮን...
# 1352  Baby B-PRODUCT\npotty I-PRODUCT\nበባትሪ O\nየሚሰራ ...
# 1353  Baby B-PRODUCT\npotty I-PRODUCT\n0905707448 O\...
# 1354  ውድ B-PRODUCT\nየሲና I-PRODUCT\nኪድስ I-PRODUCT\nደም...
#
# [1355 rows x 8 columns]

# %%
# Function to check if a string contains Amharic characters
def is_amharic(message):
    return bool(re.search(r'[\u1200-\u137F]', message))

# %%
# Function to classify messages
def classify_message(message):
    if pd.isna(message):  # Check for NaN or None
        return 'uncategorized'
    
    if is_amharic(message):
        for category, keywords in categories.items():
            if any(keyword in message for keyword in keywords):
                return category
    else:
        for category, keywords in categories.items():
            if any(keyword in message.lower() for keyword in keywords):
                return category
    return 'uncategorized'

# %%
categories = {
    'kids': [
        'toy', 'children', 'kids', 'መጫወቻ', 'play', 'games', 'fun', 'educational', 
        'puzzle', 'doll', 'action figure', 'stuffed animal', 'arts and crafts', 
        'books', 'outdoor toys', 'building blocks', 'baby', 'toddler', 'Baby',
        'መጫወቻዎች','ልጆች'
    ],
    'men': [
        'men', 'grooming', 'shaving', 'beard', 'razor', 'aftershave', 
        'scent', 'deodorant', 'grooming kit', 'haircut', 'fashion', 'suits', 
        'wallet', 'watch', 'accessories', 'fitness', 'shoes', 
        'አስተካክል', 'የብርሃን ዕቃዎች'
    ],
    'women': [
        'women', 'makeup', 'hair dryer', 'lipstick', 'foundation', 'mascara', 
        'skincare', 'nails', 'jewelry', 'dresses', 'handbags', 'accessories', 
        'fashion', 'shoes', 'perfume', 'hairstyle', 'wellness', 'beauty', 'style','Hair Drye',
        'እንቅስቃሴ', 'የፀጉር እቃዎች', 'የውበት እቃዎች'
    ],
    'sport': [
        'gym', 'GYM','fitness', 'exercise', 'እንቅስቃሴ', 'workout', 'training', 'yoga', 
        'running', 'cycling', 'sportswear', 'equipment', 'weights', 'cardio', 
        'aerobics', 'team sports', 'outdoor activities', 'athletics', 'health',  'workout', 'sports',
        'ስፖርት', 'የእንቅስቃሴ መሳሪያዎች'
    ],
    'groceries': [
        'food', 'snacks', 'grocery', 'ምግብ', 'produce', 'fruits', 'vegetables', 
        'meat', 'dairy', 'bread', 'cereal', 'beverages', 'frozen', 'canned', 
        'organic', 'bulk', 'condiments', 'spices', 'snack bars', 'breakfast', 
        'እንቁላል', 'ወተር', 'የምግብ እቃዎች'
    ],
    'accessories': [
        'jewelry', 'bags', 'accessory', 'ቀለበት', 'belts', 'hats', 'scarves', 
        'sunglasses', 'watches', 'hair accessories', 'wallets', 'phone cases', 
        'keychains', 'pins', 'brooches', 'fashion', 'style', 'gifts', 'decor', 'የልብስ መቶከሻ\n\n',
        'የመልክዕ እቃዎች', 'የምታወቅ እቃዎች','Anti-theft ',' Earbuds','PowerBank','Grip Tape','humidifier'
    ],
    'health': [
        'health', 'ጤና', 'wellness', 'nutrition', 'vitamins', 'supplements', 
        'exercise', 'fitness', 'mental health', 'meditation', 'stress relief', 
        'doctor', 'check-up', 'first aid', 'hygiene', 'immune system', 'balance', 
        'self-care', 'አንደኛ ጤና', 'የጤና እቃዎች','pulse'
    ],
    'household': [
        'cleaning', 'furniture', 'decor', 'appliances', 'utensils', 'kitchen', 
        'bathroom', 'laundry', 'storage', 'organization', 'home improvement', 'pan', 
        'gardening', 'tools', 'supplies', 'safety', 'maintenance', 'pets', 'spatulas','Kitchen','Mop',
        'spatulas\n\n','nለኪችንዎ','home', 'comfort', 'ቤት', 'የቤት እቃዎች', 'እንቅስቃሴ','bottle','ፔርሙስ','knife',
        'Glass','የላዛኛ','stove','Ironing Board','Slicer','BLENDER','MULTIFUNCTIONAL BLENDER','Toilet Brush',
        'የቢላ ስብስብ','ቢላ','Oven','fridge', 'መጥበሻ','Toilet','Mob','cookware','Blender','KITCHENWARE','ምንጣፍ','Tablemats'
    ]
}

# %%
# Apply classification to the Message column
df['Category'] = df['Message'].apply(classify_message)

# Display the updated DataFrame with categories
print(df[['Message', 'Category']])
# Out:
#                                                 Message       Category
# 0     ለኮንዶሚኒየም ለጠባብ ቤቶች ገላግሌ የሆነ ከንፁህ የሲልከን ጥሬ እቃ የተ...           kids
# 1     Baby romper   ከላዩ ፈር ውስጡ ኮተን የሆነ\n\n2000 birr\...           kids
# 2     Chicco 5 in 1 mama bag\nኦሪጅናል ማቴሪያል\nበሳይዙ ትልቅ\...      household
# 3     aiebao HIP SEAT CARRIER\nምቹ ጠንካራ የልጆች ማዘያ\nበተለ...           kids
# 4     Kids mat  \n\n4100 ብር\n\nSize 1.80*2m\n\nfree ...      household
# ...                                                 ...            ...
# 1350  ምቹ የልጆች ፖፖ የሶፍት ማስቀመጫ ያለው 1000ብር\nFree deliver...           kids
# 1351  ለልጆች ምቹ እና ኮንፈርተብል ማት \nከላይ ማጫወቻ ያለዉ ከተፈለገ ማጫወ...           kids
# 1352  Baby potty \nበባትሪ የሚሰራ ድምፅ ያለው\nየልጆች ፖፖ 899 ብር...           kids
# 1353                 Baby potty\n0905707448\n0945097042           kids
# 1354  ውድ የሲና ኪድስ ደምበኞች በድጋሚ ገብቷል \nየመዋኛ ገንዳ ትልቅ ሳይዝ ...  uncategorized
#
# [1355 rows x 2 columns]

# %%
# Display counts of unique values in the Category column
category_counts = df['Category'].value_counts()
print(category_counts)
# Out:
# Category
# kids             571
# uncategorized    437
# household        306
# men               22
# groceries         14
# sport              3
# health             2
# Name: count, dtype: int64
